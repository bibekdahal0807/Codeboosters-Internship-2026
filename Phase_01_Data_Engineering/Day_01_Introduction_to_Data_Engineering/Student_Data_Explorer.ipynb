# %% [markdown]
# MINI PROJECT: Student Data Explorer
# Onjective:
# Create a student performance explorer using python and pandas to analyze student data and generate a detailed report.
# dataset columns:
# name,
# age,
# gender,
# department,
# math_score,
# programming_score,
# attdance_performance,
# total_score
#
# Task to perform:
# 1. display project title
#   print a formatted title with separate lines
# 2. dataset overview
# display:
# -total number of students
# -total number of columns
# -number of unique departments
# 3. Department-wise Analysis
# Display the count of students in each department
# 4. Score Analysis
# Find and display:
# -Highest math score
# -Lowest math score
# -Average math score
# -Average programming score
# -Averaye attdance percentage
# 5. Gender-wise Analysis
# Calculate and display average total score grouped by gender.
# 6. Top Performers
# Display the top 5 students based on total_score.
# show:
# -student Name
# -Department
# -Total Score
# 7. Attendance Analysis
# FInd students whose attdance is below 75%
# Display:
# -Name
# -Department
# -Attdance Percentage
# If all students have attdance above 75%
# print a suitable message.
# Concept to use:
# - pandas, DataFrame, groupby(), value_counts(), mean(), max(), min(), sort_values(), interrows(), Conditional statements, f-strings

# %%
import pandas as pd

df = pd.read_csv('student_performance.csv')

# %%
print('DataFrame columns:', df.columns.tolist())
# Out:
# DataFrame columns: ['student_id', 'name', 'age', 'gender', 'department', 'semester', 'math_score', 'science_score', 'english_score', 'programming_score', 'attendance_percentage', 'city', 'admission_year', 'total_score']

# %% [markdown]
# 1. display project title print a formatted title with separate lines

# %%
print("===================================\nMINI PROJECT: Student Data Explorer\n===================================")
# Out:
# ...
# MINI PROJECT: Student Data Explorer
# ...

# %% [markdown]
# 2. dataset overview display: -total number of students -total number of columns -number of unique departments

# %%
print('Total number of Students :', df.shape[0])
print('Total number of Columns :', df.shape[1])
print('Number of unique departments:', df['department'].nunique())
# Out:
# Total number of Students : 30
# Total number of Columns : 13
# Number of unique departments: 4

# %% [markdown]
# 3. Department-wise Analysis Display the count of students in each department

# %%
print('Department Name :', df['department'].unique())

print('Department wise count of students : ')
print(df['department'].value_counts())

print("Total no of department :", df['department'].value_counts().count())
# Out:
# Department Name : ['Computer Science' 'Electronics' 'Mechanical' 'Civil']
# Department wise count of students :
# department
# Computer Science    13
# Electronics          6
# Mechanical           6
# Civil                5
# Name: count, dtype: int64
# Total no of department : 4

# %% [markdown]
# 4. Score Analysis Find and display: -Highest math score -Lowest math score -Average math score -Average programming score -Averaye attdance percentage

# %%
print('Highest math score :', df['math_score'].max())
print('Lowest math score :', df['math_score'].min())
print('Average math score :', df['math_score'].mean())
print('Average programming score :', df['programming_score'].mean())
print('Average attendance percentage :', df['attendance_percentage'].mean())
# Out:
# Highest math score : 95
# Lowest math score : 56
# Average math score : 76.06666666666666
# Average programming score : 67.6
# Average attendance percentage : 84.5

# %% [markdown]
# 5. Gender-wise Analysis Calculate and display average total score grouped by gender.

# %%
# Calculate total_score
df['total_score'] = df['math_score'] + df['programming_score']

male = df[df['gender'] == 'Male']
female = df[df['gender'] == 'Female']

print('Average total score of male students :', male['total_score'].mean())
print('Average total score of female students :', female['total_score'].mean())
# Out:
# Average total score of male students : 138.66666666666666
# Average total score of female students : 148.66666666666666

# %% [markdown]
# 6. Top Performers Display the top 5 students based on total_score. show: -student Name -Department -Total Score

# %%
# Check if df and total_score are defined, otherwise load df and calculate total_score

df['total_score'] = df['math_score'] + df['programming_score'] # Ensure total_score is calculated

# Sort by total_score in descending order and display the top 5 students
top_5_students = df.sort_values(by='total_score', ascending=False).head(5)
print('Top 5 students based on total score:')
display(top_5_students[['name', 'department', 'total_score']])
# Out:
# Top 5 students based on total score:
#               name        department  total_score
# 9       Ananya Das  Computer Science          192
# 21     Tanvi Mehta  Computer Science          189
# 4       Arjun Nair  Computer Science          187
# 29  Akanksha Yadav  Computer Science          185
# 17  Swati Kulkarni  Computer Science          182

# %% [markdown]
# 7. Attendance Analysis FInd students whose attdance is below 75% Display: -Name -Department -Attdance Percentage If all students have attdance above 75% print a suitable message

# %%
print("Attendance Analysis")
low_attendance = df[df["attendance_percentage"] < 75]
if len(low_attendance) > 0:
    print(low_attendance[["name", "department", "attendance_percentage"]])
else:
    print("All students have attendance above 75%")
# Out:
# Attendance Analysis
#              name   department  attendance_percentage
# 5     Meera Joshi  Electronics                     72
# 8    Rahul Mishra   Mechanical                     68
# 16   Manoj Pandey        Civil                     65
# 20  Harish Pillai  Electronics                     74
# 22   Sanjay Dubey        Civil                     70
# 27  Sunita Pillai        Civil                     73

# %%
import pandas as pd

# Load Dataset
df = pd.read_csv('/content/student_performance.csv')

# Project Title
print("="*50)
print("      STUDENT PERFORMANCE EXPLORER")
print("="*50)

# Dataset Overview
print("\n[1] DATASET OVERVIEW")
print("-"*30)

print("Total number of students:", df.shape[0])
print("Total number of columns:", df.shape[1])
print("Number of unique departments:", df['department'].nunique())

# Department-wise Analysis
print("\n[2] DEPARTMENT-WISE ANALYSIS")
print("-"*30)

print(df['department'].value_counts())

# Score Analysis
print("\n[3] SCORE ANALYSIS")
print("-"*30)

print("Highest Math Score:", df['math_score'].max())
print("Lowest Math Score:", df['math_score'].min())
print("Average Math Score:", round(df['math_score'].mean(),2))
print("Average Programming Score:", round(df['programming_score'].mean(),2))
print("Average Attendance Percentage:", round(df['attendance_percentage'].mean(),2))

# Create Total Score
df['total_score'] = df['math_score'] + df['programming_score']

# Gender-wise Analysis
print("\n[4] GENDER-WISE ANALYSIS")
print("-"*30)

gender_avg = df.groupby('gender')['total_score'].mean().round(2)

print(gender_avg)

# Top 5 Students
print("\n[5] TOP 5 STUDENTS")
print("-"*30)

top_students = df.sort_values(by='total_score', ascending=False).head(5)

print(top_students[['name','department','total_score']])

# Attendance Analysis
print("\n[6] ATTENDANCE ANALYSIS")
print("-"*30)

low_attendance = df[df['attendance_percentage'] < 75]

if low_attendance.empty:
    print("All students have attendance above 75%")
else:
    print(low_attendance[['name','department','attendance_percentage']])
# Out:
# ...
#       STUDENT PERFORMANCE EXPLORER
# ...
#
# [1] DATASET OVERVIEW
# ------------------------------
# Total number of students: 30
# Total number of columns: 13
# Number of unique departments: 4
#
# [2] DEPARTMENT-WISE ANALYSIS
# ------------------------------
# department
# Computer Science    13
# Electronics          6
# Mechanical           6
# Civil                5
# Name: count, dtype: int64
#
# [3] SCORE ANALYSIS
# ------------------------------
# Highest Math Score: 95
# Lowest Math Score: 56
# Average Math Score: 76.07
# Average Programming Score: 67.6
# Average Attendance Percentage: 84.5
#
# [4] GENDER-WISE ANALYSIS
# ------------------------------
# gender
# Female    148.67
# Male      138.67
# Name: total_score, dtype: float64
#
# [5] TOP 5 STUDENTS
# ------------------------------
#               name        department  total_score
# 9       Ananya Das  Computer Science          192
# 21     Tanvi Mehta  Computer Science          189
# ...
